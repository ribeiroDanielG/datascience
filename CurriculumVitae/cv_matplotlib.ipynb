# %%
Name = 'Daniel Garcia Ribeiro'
Title = 'Ciência de Dados & Analytics'
Resumo = 'Engenheiro mecânico com forte background em análises técnicas e cien-\n\
tíficas e em desenvolvimento de soluções e de produtos. Possuo experiên-\n\
cia como engenheiro de projetos na indústria agropecuária e energética\n\
e possuo conhecimentos em desenvolvimento computacional. Possuo co-\n\
nhecimento em linguagens computacionais como Python¹, Matlab e SQL.\n\
Por fim, sou uma pessoa proativa, com alta capacidade analítica e com\n\
vontade de resolver problemas, além de saber trabalhar em equipes e ser\n\
resiliente.'

TituloExperienciaProfissional = 'Experiência Profissional'
Prof1 = 'Cientista de Dados Trainee'
Prof1local= 'Banco Safra, Jun 2022 - Dez 2022'
Prof1descricao = '- Treinamento e desenvolvimento na área de dados em geral. Capacitação em\n\
linguagens de programação como Python e SQL realizada em conjunto com a\n\
edtech Ada (Let’s Code). Ambientação na área de Customer Experiencie.'
Prof2 = 'Engenheiro de projetos Trainee'
Prof2local= 'HPB Engenharia Ltda, Out 2019 - Mai 2020'
Prof2descricao = '- Documentação de projetos de caldeiras de grelha rotativa e BFB. Seleção de\n\
ventiladores centrífugos, projeto mecânico de ventiladores centrífugos, docu-\n\
mentação relacionada (RNC, SAT e relatórios), simulação fluidodinâmica com-\n\
putacional de ventiladores centrífugos, aprovação de desenhos técnicos e entre\n\
outras atividades.'

nota_rodape = '¹ Este curriculum vitae foi gerado em Python com a biblioteca Matplotlib.\n\
Veja em https://github.com/ribeiroDanielG/datascience/tree/main/Curriculum%20Vitae.'

Educacao = 'Formação Acadêmica'
edu1 = 'Doutorado em Engenharia Aeronáutica'
edu1local = 'Instituto Tecnológico de Aeronáutica\nSão José dos Campos, Brasil. 2021 - Atualmente'
edu1descricao = 'Área de concentração: Mecânica dos fluidos computacional\n\
Tema do projeto: Desenvolvimento de ferramentas computacionais para otimi-\n\
zação de simulação de escoamentos turbulentos com malhas adaptativas'
edu2 = 'Mestre em Engenharia Mecânica'
edu2local = 'Universidade de São Paulo\nSão Carlos, Brasil. 2018 - 2020'
edu2descricao = 'Área de concentração: Aeronáutica\n\
Título da dissertração: Análise paramétrica da geometria de winglets na eficiên-\n\
cia para uma pá de gerador eólico de eixo horizontal.'
edu3 = 'Bacharel em Engenharia Mecânica'
edu3local = 'Universidade Federal de São Carlos\nSão Carlos, Brasil. 2011 - 2016'
edu3descricao = 'Título da trabalho de conclusão de curso: Avaliação da influência do estado de\n\
superfície sobre as propriedades mecânicas dos aços ABNT 1020 e 1045.'

Contato = 'End.: Al. Cândido Marciano Leite, 105\n\
São José dos Campos, SP\n\
Celular: (16) 98825-2042\n\
Data de nascimento: 29/01/1993\n\
E-mail: ribeiro.danielg@gmail.com\n\
Linkedin: https://www.linkedin.com/in/\ndaniel-garcia-ribeiro/'

habilidades = 'Habilidades e competências'
hab_tec_tit = 'Técnicas:'
hab_soc_tit = 'Comportamentais:'
hab_tec = '> Matlab\n> Python\n> NumPy\n> SciPy\n> Pandas\n> Data Cleaning\n> Data Visualization\n> Scikit-learn\n> Machine learning\n(regressão, classificação\ne clusterização)\n> SQL\n>Estatística\n> MSOffice'
hab_soc = '> Proatividade\n> Independência\n> Pensamento analítico\n> Trabalho em equipe\n> Aprendizagem contínua'

idiomas = 'Idiomas'
idi_ingles = 'Inglês\nAvançado, TOEFL iBT 104'
idi_esp = 'Espanhol\nAvançado'

curso_extra = 'Cursos/Certificações'
curso_ada = "Ada - Let's Code"
curso_ada_descricao = "Trilha em Ciência de Dados\nTemas: Lógica e técncias de\nprogramação, NumPy, Pandas,\nMatplotlib, Seaborn, Plotly,\nEstatística e Machine Learning"


# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11.5))

# Decorative Lines
plt.axhline(y=.75, xmin=0.02, xmax=.64, color='#000000', linewidth=1, alpha = 0.5)
plt.axhline(y=.46, xmin=0.02, xmax=.64, color='#000000', linewidth=1, alpha = 0.5)

ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.87, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=.39, xmin=0, xmax=1, color='#ffffff', linewidth=2)
plt.axhline(y=.22, xmin=0, xmax=1, color='#ffffff', linewidth=2)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
# plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.95), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.92), weight='regular', fontsize=12)
plt.annotate(Resumo, (.02,.76), weight='regular', fontsize=10)

plt.annotate(TituloExperienciaProfissional, (.02,.72), weight='bold', fontsize=12, color='#000000')
plt.annotate(Prof1, (.02,.68), weight='bold', fontsize=10, color='#000000', alpha=0.5)
plt.annotate(Prof1local, (.02,.665), weight='regular', fontsize=9)
plt.annotate(Prof1descricao, (.03,.615), weight='regular', fontsize=9)
plt.annotate(Prof2, (.02,.57), weight='bold', fontsize=10, color='#000000', alpha=0.5)
plt.annotate(Prof2local, (.02,.552), weight='regular', fontsize=9)
plt.annotate(Prof2descricao, (.03,.475), weight='regular', fontsize=9)

plt.annotate(Educacao, (.02,.43), weight='bold', fontsize=12, color='#000000')
plt.annotate(edu1, (.02,.40), weight='bold', fontsize=10, color='#000000', alpha=0.5)
plt.annotate(edu1local, (.02,.365), weight='regular', fontsize=9)
plt.annotate(edu1descricao, (.02,.315), weight='regular', fontsize=9)
plt.annotate(edu2, (.02,.28), weight='bold', fontsize=10, color='#000000', alpha=0.5)
plt.annotate(edu2local, (.02,.245), weight='regular', fontsize=9)
plt.annotate(edu2descricao, (.02,.195), weight='regular', fontsize=9)
plt.annotate(edu3, (.02,.16), weight='bold', fontsize=10, color='#000000', alpha=0.5)
plt.annotate(edu3local, (.02,.125), weight='regular', fontsize=9)
plt.annotate(edu3descricao, (.02,.087), weight='regular', fontsize=9)

plt.annotate(nota_rodape, (.02,.05), weight='regular', fontsize=9)

plt.annotate(Contato, (.7,.89), weight='regular', fontsize=8, color='#ffffff')

plt.annotate(habilidades, (.7,.83), weight='bold', fontsize=11, color='#ffffff')
plt.annotate(hab_tec_tit, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(hab_tec, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(hab_soc_tit, (.7,.51), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(hab_soc, (.7,.413), weight='regular', fontsize=10, color='#ffffff')

plt.annotate(idiomas, (.7,.35), weight='bold', fontsize=11, color='#ffffff')
plt.annotate(idi_ingles, (.7,.30), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(idi_esp, (.7,.25), weight='regular', fontsize=10, color='#ffffff')

plt.annotate(curso_extra, (.7,.18), weight='bold', fontsize=11, color='#ffffff')
plt.annotate(curso_ada, (.7,.15), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(curso_ada_descricao, (.7,.06), weight='regular', fontsize=10, color='#ffffff')

# plt.savefig('cv.pdf', dpi=300, bbox_inches='tight')
# Out:
# Text(0.7, 0.06, 'Trilha em Ciência de Dados\nTemas: Lógica e técncias de\nprogramação, NumPy, Pandas,\nMatplotlib, Seaborn, Plotly,\nEstatística e Machine Learning')
